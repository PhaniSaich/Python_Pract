# %% [markdown]
# <a href="https://colab.research.google.com/github/PhaniSaich/Python_Pract/blob/p1/function_args.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fn1(fn_a,fn_b):
  print(f"fn_a = {fn_a}")
  print(f"fn_b = {fn_b}")

# %%
def fn2(fn_a,fn_b=1):
  print(f"fn_a = {fn_a}")
  print(f"fn_b = {fn_b}")

# %%
a = 99
b = 10

# %%
fn1(a,b)
# Out:
# fn_a = 99
# fn_b = 10

# %%
fn1(b,a)
# Out:
# fn_a = 10
# fn_b = 99

# %%
fn1(fn_a=a,fn_b=b)
# Out:
# fn_a = 99
# fn_b = 10

# %%
fn1(fn_b=b,fn_a=a)
# Out:
# fn_a = 99
# fn_b = 10

# %%
fn2(fn_b=b,fn_a=a)
# Out:
# fn_a = 99
# fn_b = 10

# %%
fn2(fn_a=a)
# Out:
# fn_a = 99
# fn_b = 1

# %%
fn2(a,b)
# Out:
# fn_a = 99
# fn_b = 10

# %%
fn2(a)
# Out:
# fn_a = 99
# fn_b = 1

# %%
fn2(fn_b=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-568784062.py in <cell line: 0>()
# ----> 1 fn2(fn_b=10)
#
# TypeError: fn2() missing 1 required positional argument: 'fn_a'

# %%
def fn_args(*args):
  print(*args)
  length = len(args)
  print(length)
  print(type(args))

# %%
fn_args(1)
# Out:
# 1
# 1
# <class 'tuple'>

# %%
fn_args(1,2)
# Out:
# 1 2
# 2
# <class 'tuple'>

# %%
fn_args()
# Out:
# 0
# <class 'tuple'>

# %%
fn_args(1,2,3,4,5,6,7,8,9,0)
# Out:
# 1 2 3 4 5 6 7 8 9 0
# 10
# <class 'tuple'>

# %%
def named_param_fn(**kwargs):
  print(kwargs)
  l = len(kwargs)

  print("length = ",l)
  print(type(kwargs))

# %%
named_param_fn(a=1)
# Out:
# {'a': 1}
# length =  1
# <class 'dict'>

# %%
named_param_fn(a=1,b=2)
# Out:
# {'a': 1, 'b': 2}
# length =  2
# <class 'dict'>

# %%
def car_fn(**cargs_args):
  keys = list(cargs_args.keys())
  if "car_type" in keys:
    car_type = cargs_args["car_type"]
    print(f"car_type = {car_type}")
  if "car_color" in keys:
    car_color = cargs_args["car_color"]
    print(f"car_color = {car_color}")
  print(cargs_args)

# %%
car_fn(car_type="Hatchback")
car_fn(car_type="Muv")
# Out:
# car_type = Hatchback
# {'car_type': 'Hatchback'}
# car_type = Muv
# {'car_type': 'Muv'}

# %%
car_fn(car_type="Hatchback",car_color = "Grey")
car_fn(car_type="Muv",car_color="Ash")
# Out:
# car_type = Hatchback
# car_color = Grey
# {'car_type': 'Hatchback', 'car_color': 'Grey'}
# car_type = Muv
# car_color = Ash
# {'car_type': 'Muv', 'car_color': 'Ash'}

# %%
car_fn(car_type="Hatchback",car_color = "Grey",Milage="20")
car_fn(car_type="Muv",car_color="Ash",Milage="22")
# Out:
# {'car_type': 'Hatchback', 'car_color': 'Grey', 'Milage': '20'}
# {'car_type': 'Muv', 'car_color': 'Ash', 'Milage': '22'}
