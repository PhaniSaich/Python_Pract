# %% [markdown]
# <a href="https://colab.research.google.com/github/PhaniSaich/Python_Pract/blob/p1/Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = """
  This is multi line string

"""
b= '''
This is another multi line string

'''

# %%
print(a)
print(b)
# Out:
#   This is multi line string
#
#
#
# This is another multi line string

# %%
a=[["a","b"],[1,2,[3]]]

# %%
print(a)
# Out:
# [['a', 'b'], [1, 2, [3]]]

# %%
t = (1,2,3,["a","b"],("t1"))

# %%
t
# Out:
# (1, 2, 3, ['a', 'b'], 't1')

# %%
a=[["a","b"],[1,2,(3,4)]]

# %%
a
# Out:
# [['a', 'b'], [1, 2, (3, 4)]]

# %%
a.append("a")

# %%
a = [1,2,3,4,5,6,7]
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a[0:7:4]
# Out:
# [1, 5]

# %%
a="Hello,world"
b = a.split(",")
print(b)
# Out:
# ['Hello', 'world']

# %%
Taks read file from python

# %%
s =  {1,2,3,4,1}
l = [1,2,
     3,


     4,1]
print(s)
print(l)
# Out:
# {1, 2, 3, 4}
# [1, 2, 3, 4, 1]

# %%
list(set(l))
# Out:
# [1, 2, 3, 4]

# %%
a = {"k1":"v1","k11":
                  {"inner_k1":"inner_v1","ik2":[1,2,3]}
     }
type(a)
# Out:
# dict

# %%
a["k1"]
# Out:
# 'v1'

# %%
c = a["k11"]
print(c)
# Out:
# {'inner_k1': 'inner_v1', 'ik2': [1, 2, 3]}

# %%
c["inner_k1"]
# Out:
# 'inner_v1'

# %%
a["k11"]["inner_k1"]
# Out:
# 'inner_v1'

# %%
c["ik2"]
# Out:
# [1, 2, 3]

# %%
d = a["k11"]["ik2"]
d
# Out:
# [1, 2, 3]

# %%
a["k11"]["ik2"][1]
# Out:
# 2

# %%
for ele in a["k11"]["ik2"]:
  print(ele)
# Out:
# 1
# 2
# 3

# %%
b = a["k11"]["ik2"]
b
# Out:
# [1, 2, 3]

# %%
b[1]
# Out:
# 2

# %%
a["k11"]["ik2"][1]
# Out:
# 2

# %%
a
# Out:
# {'k1': 'v1', 'k11': {'inner_k1': 'inner_v1', 'ik2': [1, 2, 3]}}

# %%
keys = a.keys()
tuple(keys)
# Out:
# ('k1', 'k11')

# %%
values = a.values()
tuple(values)
# Out:
# ('v1', {'inner_k1': 'inner_v1', 'ik2': [1, 2, 3]})

# %%
a.items()
# Out:
# dict_items([('k1', 'v1'), ('k11', {'inner_k1': 'inner_v1', 'ik2': [1, 2, 3]})])

# %%
for key,value in a.items():
  print(f"key = {key}")#print("key = ", key)
  print(f"value = {value}")
# Out:
# key = k1
# value = v1
# key = k11
# value = {'inner_k1': 'inner_v1', 'ik2': [1, 2, 3]}

# %%
l
# Out:
# [1, 2, 3, 4, 1]

# %%
for ele in l:
  print(ele)
# Out:
# 1
# 2
# 3
# 4
# 1

# %%
from datetime import datetime
for index,ele in enumerate(l):
  file_no = index + 1

  a = datetime.now()
  print(f"---------------------Processing file = {file_no}, loading started at  - {a}-------------------------")
  #print("ele = ", ele)
# Out:
# ---------------------Processing file = 1, loading started at  - 2025-08-12 18:02:39.308060-------------------------
# ---------------------Processing file = 2, loading started at  - 2025-08-12 18:02:39.308123-------------------------
# ---------------------Processing file = 3, loading started at  - 2025-08-12 18:02:39.308136-------------------------
# ---------------------Processing file = 4, loading started at  - 2025-08-12 18:02:39.308145-------------------------
# ---------------------Processing file = 5, loading started at  - 2025-08-12 18:02:39.308153-------------------------

# %%
print(a)
# Out:
# 2025-08-12 18:01:26.688274
